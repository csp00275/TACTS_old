# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np

# 1. 기본 스타일 설정
plt.style.use('default')
plt.rcParams['figure.figsize'] = (8,2)
plt.rcParams['font.size'] = 12

# 2. 필요한 변수 지정

D = 200 
d = 100
R = D/2
r = d/2
L = 160
W = round(2*np.pi*R,0)
alpha = np.deg2rad(27)

nx = 12
ny = 2

# 3. 그래프 그리기
fig, ax = plt.subplots()

ax.set_xlim(0, W)
ax.set_ylim(0, L)
ax.set_xlabel('width')
ax.set_ylabel('height')
plt.title('LABSv3 D: {0} d:{1}'.format(D,d))


# 4. 사각형 그리기
ax.add_patch(
   patches.Rectangle(
      (0, 0),                   # (x, y)
      W, L,                     # width, height
      edgecolor = 'lightblue',
      facecolor = 'lightblue',
      fill=True,
   ))
for j in range(0,ny):
    for i in range(0,nx):
        ax.add_patch(
       patches.Ellipse(
          (W/nx*(i+1/2), 50+j*60),                   # (x, y)
          (R-r)/np.cos(alpha/2)*alpha, (R-r)*2*np.tan(alpha/2),                     # width, height
          edgecolor = 'red',
          facecolor = 'red',
          fill=True,
       ))
#         ax.add_patch(
#        patches.Ellipse(
#           (2*np.pi*R/nx*(i), 80),                   # (x, y)
#           (R-r)/np.cos(alpha/2)*alpha, (R-r)*2*np.tan(alpha/2),                     # width, height
#           edgecolor = 'red',
#           facecolor = 'red',
#           fill=True,
#        ))


ax.add_patch(
   patches.Rectangle(
      (W/nx/2, 50),           # (x, y)
      round(W/nx,1), 1,                     # width, height
      edgecolor = 'black',
      facecolor = 'black',
      fill=True,
   ))

plt.text(W/nx-25, 20,'{0}'.format(round(W/nx,1)))

# 세로 길이
ax.add_patch(
   patches.Rectangle(
      (W/nx/2-1, 50),           # (x, y)
      1, dy,                     # width, height
      edgecolor = 'black',
      facecolor = 'black',
      fill=True,
   ))

plt.text(W/nx/2+5, dy/2+45,'{0}'.format(dy))

       
        
# 5. 텍스트 삽입하기

plt.show()

print('number of sensors : {0}'.format(nx*ny))
print('Length : {0}   Height : {1}  Ratio : {2}'.format(W,L,round(W/L,0)))
print('Radius of Circle : {0}'.format(max((R-r)/np.cos(alpha/2)*alpha, (R-r)*2*np.tan(alpha/2))))
# Out:
# number of sensors : 24
# Length : 628.0   Height : 160  Ratio : 4.0
# Radius of Circle : 24.231462129440576

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np

# 1. 기본 스타일 설정
plt.style.use('default')
plt.rcParams['figure.figsize'] = (12,2)
plt.rcParams['font.size'] = 12

# 2. 필요한 변수 지정

D = 300 
d = 200
R = D/2
r = d/2
L = 150
W = round(2*np.pi*R,0)
alpha = np.deg2rad(27)

nx = 16
ny = 2
dy = 60
yi = L/2-dy/2

# 3. 그래프 그리기
fig, ax = plt.subplots()

ax.set_xlim(0, W)
ax.set_ylim(0, L)
ax.set_xlabel('width')
ax.set_ylabel('height')
titleName = 'ForeArm'
plt.title(titleName+'  '+'D: {0} d:{1}'.format(D,d))

# 4. 사각형 그리기
ax.add_patch(
   patches.Rectangle(
      (0, 0),                   # (x, y)
      W, L,                     # width, height
      edgecolor = 'lightblue',
      facecolor = 'lightblue',
      fill=True,
   ))

ax.add_patch(
   patches.Rectangle(
      (0, yi-20),                   # (x, y)
      W, dy+2*20,                     # width, height
      edgecolor = 'lightyellow',
      facecolor = 'lightyellow',
      fill=True,
   ))

for j in range(0,ny):
    for i in range(0,nx):
        ax.add_patch(
       patches.Ellipse(
          (W/nx*(i+1/2), yi+j*dy),                   # (x, y)
          (R-r)/np.cos(alpha/2)*alpha, (R-r)*2*np.tan(alpha/2),                     # width, height
          edgecolor = 'red',
          facecolor = 'red',
          fill=True,
       ))
#         ax.add_patch(
#        patches.Ellipse(
#           (2*np.pi*R/nx*(i), 80),                   # (x, y)
#           (R-r)/np.cos(alpha/2)*alpha, (R-r)*2*np.tan(alpha/2),                     # width, height
#           edgecolor = 'red',
#           facecolor = 'red',
#           fill=True,
#        ))

# 가로 길이
ax.add_patch(
   patches.Rectangle(
      (W/nx/2, yi),           # (x, y)
      round(W/nx,2), 1,                     # width, height
      edgecolor = 'black',
      facecolor = 'black',
      fill=True,
   ))

plt.text(W/nx-25, 20,'{0}'.format(round(W/nx,2)))

# 세로 길이
ax.add_patch(
   patches.Rectangle(
      (W/nx/2-1, yi),           # (x, y)
      1, dy,                     # width, height
      edgecolor = 'black',
      facecolor = 'black',
      fill=True,
   ))

plt.text(W/nx/2-25, dy/2+45,'{0}'.format(dy))

       
        
# 5. 텍스트 삽입하기

plt.show()

print('number of sensors : {0}'.format(nx*ny))
print('Length : {0}   Height : {1}  Ratio : {2}'.format(W,L,round(W/L,0)))
print('Radius of Circle : {0}'.format(max((R-r)/np.cos(alpha/2)*alpha, (R-r)*2*np.tan(alpha/2))))
print('Yellow Box Height : {0}'.format(dy+2*20))
# Out:
# number of sensors : 32
# Length : 942.0   Height : 150  Ratio : 6.0
# Radius of Circle : 24.231462129440576
# Yellow Box Height : 100

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np

# 1. 기본 스타일 설정
plt.style.use('default')
plt.rcParams['figure.figsize'] = (12,4)
plt.rcParams['font.size'] = 12

# 2. 필요한 변수 지정

D = 300 
d = 150
R = D/2
r = d/2
L = 300
W = round(2*np.pi*R,0)
alpha = np.deg2rad(27)

nx = 16
ny = 3
dy = 60
yi = L/2-dy

# 3. 그래프 그리기
fig, ax = plt.subplots()

ax.set_xlim(0, W)
ax.set_ylim(0, L)
ax.set_xlabel('width')
ax.set_ylabel('height')
titleName = 'UpperArm'
plt.title(titleName+'  '+'D: {0} d:{1}'.format(D,d))


# 4. 사각형 그리기
ax.add_patch(
   patches.Rectangle(
      (0, 0),                   # (x, y)
      W, L,                     # width, height
      edgecolor = 'lightblue',
      facecolor = 'lightblue',
      fill=True,
   ))

ax.add_patch(
   patches.Rectangle(
      (0, yi-20),                   # (x, y)
      W, 2*dy+20*2,                     # width, height
      edgecolor = 'lightyellow',
      facecolor = 'lightyellow',
      fill=True,
   ))
       
for j in range(0,ny):
    for i in range(0,nx):
        ax.add_patch(
       patches.Ellipse(
          (W/nx*(i+1/2), yi+j*dy),                   # (x, y)
          (R-r)/np.cos(alpha/2)*alpha, (R-r)*2*np.tan(alpha/2),                     # width, height
          edgecolor = 'red',
          facecolor = 'red',
          fill=True,
       ))
#         ax.add_patch(
#        patches.Ellipse(
#           (2*np.pi*R/nx*(i), 80),                   # (x, y)
#           (R-r)/np.cos(alpha/2)*alpha, (R-r)*2*np.tan(alpha/2),                     # width, height
#           edgecolor = 'red',
#           facecolor = 'red',
#           fill=True,
#        ))


ax.add_patch(
   patches.Rectangle(
      (W/nx/2, yi),           # (x, y)
      round(W/nx,2), 1,                     # width, height
      edgecolor = 'black',
      facecolor = 'black',
      fill=True,
   ))

plt.text(W/nx-25, yi-30,'{0}'.format(round(W/nx,2)))

# 세로 길이
ax.add_patch(
   patches.Rectangle(
      (W/nx/2-1, yi),           # (x, y)
      1, dy,                     # width, height
      edgecolor = 'black',
      facecolor = 'black',
      fill=True,
   ))

plt.text(W/nx/2-25, yi+dy/2,'{0}'.format(dy))


        
# 5. 텍스트 삽입하기

plt.show()

print('number of sensors : {0}'.format(nx*ny))
print('Length : {0}   Height : {1}  Ratio : {2}'.format(W,L,round(W/L,0)))
print('Radius of Circle : {0}'.format(max((R-r)/np.cos(alpha/2)*alpha, (R-r)*2*np.tan(alpha/2))))
print('Yellow Box Height : {0}'.format(2*dy+2*20))
# Out:
# number of sensors : 48
# Length : 942.0   Height : 300  Ratio : 3.0
# Radius of Circle : 36.347193194160866
# Yellow Box Height : 160

# %%
max((R-r)/np.cos(alpha/2)*alpha,(R-r)*2*np.tan(alpha/2))
# Out:
# 24.231462129440576
