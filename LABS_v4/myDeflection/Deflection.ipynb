# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# %%
#line A-B
R = 110
n = 100
L = 160

ABx =[0]*n
ABy = list(np.arange(0,R,R/n))

BCx = list(np.arange(0,L+1,(L+1)/n))
BCy = [110]*n

CDx = [L]*n
CDy = list(np.arange(0,R,R/n))

# %%
print("ListLength","ABx :",len(ABx),"    ABy :",len(ABy), "    CDx :", len(CDx), "    CDy :", len(CDy))
# Out:
# ListLength ABx : 100     ABy : 100     CDx : 100     CDy : 100

# %%
plt.plot(ABx,ABy,color='b')
plt.plot(BCx,BCy,color='b')
plt.plot(CDx,CDy,color='b')


# Force point
shp=matplotlib.patches.Circle((60,110), radius=2, color='r')

plt.gca().add_patch(shp)
plt.show()

# %%
E = 60*10**6
I = 10*10**6
p = 2*10**3
Bx = 0


x = np.arange(0,110,0.1)
plt.plot((Bx*x**3)/(3*E*I)-(p*x**4)/(8*E*I),x,color='b')
plt.show()

# %% [markdown]
# # 3D Scatter plot

# %%
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.gca(projection = '3d')

#Make data.

n = 100

r = list(np.arange(100,210,(110)/n))
theta = list(np.arange(0,2*np.pi,(2*np.pi)/n))

X = np.arange(0,161,(160)/10)
Y = r*np.cos(theta)
Z = r*np.sin(theta)

ax.scatter(X,Y,Z)
plt.show()
# Out:
# C:\Users\JH_LAB\AppData\Local\Temp/ipykernel_44624/2324315666.py:5: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection = '3d')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_44624/2324315666.py in <module>
#      16 Z = r*np.sin(theta)
#      17
# ---> 18 ax.scatter(X,Y,Z)
#      19 plt.show()
#      20
#
# ~\anaconda3\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py in scatter(self, xs, ys, zs, zdir, s, c, depthshade, *args, **kwargs)
#    2404         zs_orig = zs
#    2405
# -> 2406         xs, ys, zs = np.broadcast_arrays(
#    2407             *[np.ravel(np.ma.filled(t, np.nan)) for t in [xs, ys, zs]])
#    2408         s = np.ma.ravel(s)  # This doesn't have to match x, y in size.
#
# <__array_function__ internals> in broadcast_arrays(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\stride_tricks.py in broadcast_arrays(subok, *args)
#     536     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     537
# --> 538     shape = _broadcast_shape(*args)
#     539
#     540     if all(array.shape == shape for array in args):
#
# ~\anaconda3\lib\site-packages\numpy\lib\stride_tricks.py in _broadcast_shape(*args)
#     418     # use the old-iterator because np.nditer does not handle size 0 arrays
#     419     # consistently
# --> 420     b = np.broadcast(*args[:32])
#     421     # unfortunately, it cannot handle 32 or more arguments directly
#     422     for pos in range(32, len(args), 31):
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape

# %%
import numpy as np

def data_for_cylinder_along_z(center_x,center_y,radius,height_z):
    z = np.linspace(0, height_z, 50)
    theta = np.linspace(0, np.pi, 50)
    theta_grid, z_grid=np.meshgrid(theta, z)
    x_grid = radius*np.cos(theta_grid) + center_x
    y_grid = radius*np.sin(theta_grid) + center_y
    return x_grid,y_grid,z_grid

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

Xc,Yc,Zc = data_for_cylinder_along_z(0.2,0.2,0.05,0.1)
ax.scatter(Zc, Xc, Yc, alpha=0.1)

plt.show()
