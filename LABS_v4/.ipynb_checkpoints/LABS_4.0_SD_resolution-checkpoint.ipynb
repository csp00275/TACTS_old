# %%
import os, sklearn, math
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
import matplotlib.pyplot as plt
from joblib import dump, load

tf.random.set_seed(42)

def LoadData():
    data = '220408_Data'
    dataname = data+'_01'
    filename = 'myData/'+data+'.csv'
    SD = pd.read_csv(filename)
    SD=SD.iloc[:,:11]
    SensorData = SD
    return SD
SD = LoadData()

# %%
SD
# Out:
#         Sx00   Sx01   Sx02   Sx03   Sx04   Sx05   Sx06    r   theta   z
# 0      36.95  46.51  55.44  56.02  33.97  71.28  63.43  0.6  359.96   0
# 1      37.80  48.72  53.37  58.88  32.98  76.89  58.13  0.6  359.96   0
# 2      36.95  45.40  54.41  59.84  38.93  68.47  60.25  0.6  359.96   0
# 3      38.65  47.62  56.48  57.93  34.96  71.28  59.19  0.6  359.96   0
# 4      37.80  49.83  54.41  57.93  32.98  71.28  59.19  0.6  359.96   0
# ...      ...    ...    ...    ...    ...    ...    ...  ...     ...  ..
# 24083  36.11  54.26  50.26  55.07  49.83  60.04  41.17  1.8    0.48  84
# 24084  36.11  49.83  48.19  54.11  43.88  53.02  40.11  1.8    0.48  84
# 24085  36.95  47.62  49.23  53.16  39.92  53.02  41.17  1.8    0.48  84
# 24086  36.11  50.94  52.33  55.07  42.89  54.43  43.29  1.8    0.48  84
# 24087  36.11  49.83  50.26  52.21  46.85  55.83  41.17  1.8    0.48  84
#
# [24088 rows x 10 columns]

# %%
SD.describe()
# Out:
#                Sx00          Sx01          Sx02          Sx03          Sx04  \
# count  24088.000000  24088.000000  24088.000000  24088.000000  24088.000000
# mean      37.024831     49.221248     47.854135     51.704367     31.787865
# std        1.651854      5.096672      5.164318      5.266217     16.412088
# min       31.020000     26.580000     28.510000     34.080000    -26.480000
# 25%       36.110000     46.510000     45.080000     48.390000     20.100000
# 50%       36.950000     49.830000     49.230000     52.210000     33.970000
# 75%       37.800000     53.150000     51.300000     56.020000     44.870000
# max       44.590000     63.110000     59.590000     63.650000     65.680000
#
#                Sx05          Sx06             r         theta             z
# count  24088.000000  24088.000000  24088.000000  24088.000000  24088.000000
# mean      63.339488     56.568207      1.199759    292.777009     41.997675
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
SD.hist(bins=50, figsize=(20,15))
plt.show()

# %%
# 센서데이터 솎아내기
SDext =SD # SensorData[SensorData['z']==0]
mask = SDext["r"].isin([0.6])
SD = SDext[mask]
SD
# Out:
#         Sx00   Sx01   Sx02   Sx03   Sx04   Sx05   Sx06    r   theta   z
# 0      36.95  46.51  55.44  56.02  33.97  71.28  63.43  0.6  359.96   0
# 1      37.80  48.72  53.37  58.88  32.98  76.89  58.13  0.6  359.96   0
# 2      36.95  45.40  54.41  59.84  38.93  68.47  60.25  0.6  359.96   0
# 3      38.65  47.62  56.48  57.93  34.96  71.28  59.19  0.6  359.96   0
# 4      37.80  49.83  54.41  57.93  32.98  71.28  59.19  0.6  359.96   0
# ...      ...    ...    ...    ...    ...    ...    ...  ...     ...  ..
# 23604  36.11  56.47  53.37  56.02  -6.66  62.85  52.83  0.6    0.53  84
# 23605  37.80  50.94  51.30  55.07  -3.69  58.64  52.83  0.6    0.53  84
# 23606  36.11  48.72  53.37  56.02  -1.70  58.64  52.83  0.6    0.53  84
# 23607  36.95  55.37  50.26  56.02 -12.61  64.26  49.65  0.6    0.53  84
# 23608  36.95  49.83  50.26  55.07   1.27  67.06  51.77  0.6    0.53  84
#
# [3448 rows x 10 columns]

# %%
SD.plot(kind="scatter", x= "z",y= "Sx00",alpha = 0.1)
SD.plot(kind="scatter", x= "z",y= "Sx01",alpha = 0.1)
SD.plot(kind="scatter", x= "z",y= "Sx02",alpha = 0.1)
SD.plot(kind="scatter", x= "z",y= "Sx03",alpha = 0.1)
SD.plot(kind="scatter", x= "z",y= "Sx04",alpha = 0.1)
SD.plot(kind="scatter", x= "z",y= "Sx05",alpha = 0.1)
SD.plot(kind="scatter", x= "z",y= "Sx06",alpha = 0.1)
# Out:
# <AxesSubplot:xlabel='z', ylabel='Sx06'>

# %%
import numpy as np
import matplotlib.pyplot as plt

x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)

y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

plt.subplot(2, 1, 1)                # nrows=2, ncols=1, index=1
plt.plot(x1, y1, 'o-')
plt.title('1st Graph')
plt.ylabel('Damped oscillation')

plt.subplot(2, 1, 2)                # nrows=2, ncols=1, index=2
plt.plot(x2, y2, '.-')
plt.title('2nd Graph')
plt.xlabel('time (s)')
plt.ylabel('Undamped')

plt.tight_layout()
plt.show()

SD = LoadData()
X = SD['Sx00']
Y = SD['r']
Z = SD['z']

plot_geeks = ax.scatter(X, Y, Z, color='green')
plt.show()
# Out:
# C:\Users\JH_LAB\AppData\Local\Temp/ipykernel_19752/3695644307.py:5: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %%
import numpy as np
import matplotlib.pyplot as plt

r = [0.6,0.8,1.0,1.2,1.4,1.6,1.8]

for rdata in r:
    SD = LoadData()
    mask = SD["r"].isin([rdata])
    SDr = SD[mask]
    SDr.plot(kind="scatter", x= "z",y= "Sx00",alpha = 0.1)

# %%
import numpy as np
import matplotlib.pyplot as plt

############ PUT SENSOR NUM ################

senNum = "Sx00" # Sx00 - Sx06

############################################



r = [0.6,0.8,1.0,1.2,1.4,1.6,1.8]

for rdata in r:
    SD = LoadData()
    mask = SD["r"].isin([rdata])
    SDr = SD[mask]
    SDr.plot(kind="scatter", x= "z",y= senNum,alpha = 0.1)
