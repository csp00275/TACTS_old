# %%
import os, sklearn, math
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
import matplotlib.pyplot as plt
from joblib import dump, load

tf.random.set_seed(42)

data = '220408_Data'
dataname = data+'_20'
filename = 'myData/'+data+'.csv'
SD = pd.read_csv(filename)
SD=SD.iloc[:,:11]
SensorData = SD

# %%
SD.describe()
# Out:
#                Sx00          Sx01          Sx02          Sx03          Sx04  \
# count  24088.000000  24088.000000  24088.000000  24088.000000  24088.000000
# mean      37.024831     49.221248     47.854135     51.704367     31.787865
# std        1.651854      5.096672      5.164318      5.266217     16.412088
# min       31.020000     26.580000     28.510000     34.080000    -26.480000
# 25%       36.110000     46.510000     45.080000     48.390000     20.100000
# 50%       36.950000     49.830000     49.230000     52.210000     33.970000
# 75%       37.800000     53.150000     51.300000     56.020000     44.870000
# max       44.590000     63.110000     59.590000     63.650000     65.680000
#
#                Sx05          Sx06             r         theta             z
# count  24088.000000  24088.000000  24088.000000  24088.000000  24088.000000
# mean      63.339488     56.568207      1.199759    292.777009     41.997675
# std        8.116793      4.087278      0.400081    137.427494     24.819033
# min       37.580000     35.870000      0.600000      0.000000      0.000000
# 25%       57.240000     54.950000      0.800000    349.850000     20.000000
# 50%       65.660000     57.070000      1.200000    358.950000     42.000000
# 75%       69.870000     59.190000      1.600000    359.820000     64.000000
# max       81.100000     65.550000      1.800000    359.960000     84.000000

# %%
SDext =SD # SensorData[SensorData['z']==0]
mask = SDext["z"].isin(list(range(0,20,2))+list(range(82,86,2)))
SD = SDext[~mask]
SD.describe()
# Out:
#                Sx00          Sx01          Sx02          Sx03          Sx04  \
# count  17366.000000  17366.000000  17366.000000  17366.000000  17366.000000
# mean      37.156484     49.864177     46.295321     49.733757     31.407090
# std        1.397612      4.680263      5.134087      4.802136     14.765704
# min       32.710000     28.800000     28.510000     34.080000    -26.480000
# 25%       36.110000     47.620000     43.010000     46.480000     20.100000
# 50%       36.950000     50.940000     47.150000     50.300000     32.980000
# 75%       37.800000     53.150000     50.260000     53.160000     42.890000
# max       42.890000     63.110000     58.550000     60.790000     65.680000
#
#                Sx05          Sx06             r         theta             z
# count  17366.000000  17366.000000  17366.000000  17366.000000  17366.000000
# mean      61.044042     56.208071      1.199804    299.572531     50.001843
# std        7.753226      3.540908      0.400083    133.874508     17.888672
# min       37.580000     41.170000      0.600000      0.000000     20.000000
# 25%       55.830000     54.950000      0.800000    358.770000     34.000000
# 50%       62.850000     57.070000      1.200000    359.780000     50.000000
# 75%       67.060000     59.190000      1.600000    359.870000     66.000000
# max       78.300000     64.490000      1.800000    359.960000     80.000000

# %%
import numpy as np
SD['r'] = (SD['r']-SD['r'].mean())/(SD['r'].max()-SD['r'].min())*2
SD['z'] = (SD['z']-SD['z'].mean())/(SD['z'].max()-SD['z'].min())*2
SD.describe()
# Out:
# C:\Users\JH_LAB\AppData\Local\Temp/ipykernel_15780/1877745495.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SD['r'] = (SD['r']-SD['r'].mean())/(SD['r'].max()-SD['r'].min())*2
# C:\Users\JH_LAB\AppData\Local\Temp/ipykernel_15780/1877745495.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SD['z'] = (SD['z']-SD['z'].mean())/(SD['z'].max()-SD['z'].min())*2
#                Sx00          Sx01          Sx02          Sx03          Sx04  \
# count  17366.000000  17366.000000  17366.000000  17366.000000  17366.000000
# mean      37.156484     49.864177     46.295321     49.733757     31.407090
# std        1.397612      4.680263      5.134087      4.802136     14.765704
# min       32.710000     28.800000     28.510000     34.080000    -26.480000
# 25%       36.110000     47.620000     43.010000     46.480000     20.100000
# 50%       36.950000     50.940000     47.150000     50.300000     32.980000
# 75%       37.800000     53.150000     50.260000     53.160000     42.890000
# max       42.890000     63.110000     58.550000     60.790000     65.680000
#
#                Sx05          Sx06             r         theta             z
# count  17366.000000  17366.000000  1.736600e+04  17366.000000  1.736600e+04
# mean      61.044042     56.208071  1.102741e-13    299.572531  1.263290e-14
# std        7.753226      3.540908  6.668057e-01    133.874508  5.962891e-01
# min       37.580000     41.170000 -9.996737e-01      0.000000 -1.000061e+00
# 25%       55.830000     54.950000 -6.663404e-01    358.770000 -5.333948e-01
# 50%       62.850000     57.070000  3.263081e-04    359.780000 -6.142270e-05
# 75%       67.060000     59.190000  6.669930e-01    359.870000  5.332719e-01
# max       78.300000     64.490000  1.000326e+00    359.960000  9.999386e-01

# %%
#%matplotlib inline
#import matplotlib.pyplot as plt
#SD.hist(bins=50, figsize=(20,15))
#plt.show()

# %%
X = SD.iloc[:,[1,2,3,4,5,6]]
y = SD.iloc[:,[7,9]]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

X_train_full, X_test, y_train_full, y_test = train_test_split(X, y, test_size = 0.01, random_state=42)
X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train_full, test_size = 0.2, random_state=42)

# %%
X_sum = len(X_train)+len(X_valid)+len(X_test)
X_train_per = int(len(X_train)/X_sum*100)
X_valid_per = int(len(X_valid)/X_sum*100)
X_test_per = int(len(X_test)/X_sum*100)

print('X_train: ',len(X_train),'ea',X_train_per,'%   ', 
      'X_valid: ',len(X_valid),'ea',X_valid_per,'%   ',
      'X_test: ',len(X_test),'ea',X_test_per,'%',)
# Out:
# X_train:  13753 ea 79 %    X_valid:  3439 ea 19 %    X_test:  174 ea 1 %

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_valid = scaler.transform(X_valid)
X_test = scaler.transform(X_test)

# %%
import pickle
from joblib import dump, load

file_name = 'myScaler/'+dataname+'_SS.pkl'
dump(scaler, file_name)
# Out:
# ['myScaler/220408_Data_20_SS.pkl']

# %%
 from tensorflow import keras
model = keras.models.Sequential([    
    keras.layers.Dense(64, activation="elu", input_shape=X_train.shape[1:],kernel_initializer = "he_normal"),
    keras.layers.Dense(64, activation="elu", input_shape=X_train.shape[1:],kernel_initializer = "he_normal"),
    keras.layers.Dense(32, activation="elu", input_shape=X_train.shape[1:],kernel_initializer = "he_normal"),
    keras.layers.Dense(32, activation="elu", input_shape=X_train.shape[1:],kernel_initializer = "he_normal"),
    keras.layers.Dense(16, activation="elu", input_shape=X_train.shape[1:],kernel_initializer = "he_normal"),
    keras.layers.Dense(16, activation="elu", input_shape=X_train.shape[1:],kernel_initializer = "he_normal"),
    keras.layers.Dense(8, activation="elu", input_shape=X_train.shape[1:],kernel_initializer = "he_normal"),
    keras.layers.Dense(2)
])
#model.compile(loss="mean_squared_error", optimizer=keras.optimizers.SGD(learning_rate=1e-3, momentum = 0.9,nesterov = True))
model.compile(loss="mean_squared_error", optimizer=keras.optimizers.RMSprop(learning_rate=1e-5, rho = 0.9))
model.summary()
# Out:
# Model: "sequential_49"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_416 (Dense)           (None, 64)                448
#
#  dense_417 (Dense)           (None, 64)                4160
#
#  dense_418 (Dense)           (None, 32)                2080
#
#  dense_419 (Dense)           (None, 32)                1056
#
#  dense_420 (Dense)           (None, 16)                528
#
#  dense_421 (Dense)           (None, 16)                272
#
#  dense_422 (Dense)           (None, 8)                 136
#
#  dense_423 (Dense)           (None, 2)                 18
#
# =================================================================
# Total params: 8,698
# Trainable params: 8,698
# Non-trainable params: 0
# _________________________________________________________________

# %%
import os 
root_logdir = os.path.join(os.curdir, 'mylog/'+data)

def get_run_logdir():
    import time
    run_id= time.strftime("%m%d_%Hh%Mm%Ss"+dataname)
    return os.path.join(root_logdir, run_id)

run_logdir = get_run_logdir()

# %%
K = keras.backend
class OneCycleScheduler(keras.callbacks.Callback):
    def __init__(self, iterations, max_rate, start_rate=None,
                 last_iterations=None, last_rate=None):
        self.iterations = iterations
        self.max_rate = max_rate
        self.start_rate = start_rate or max_rate / 10
        self.last_iterations = last_iterations or iterations // 10 + 1
        self.half_iteration = (iterations - self.last_iterations) // 2
        self.last_rate = last_rate or self.start_rate / 1000
        self.iteration = 0
    def _interpolate(self, iter1, iter2, rate1, rate2):
        return ((rate2 - rate1) * (self.iteration - iter1)
                / (iter2 - iter1) + rate1)
    def on_batch_begin(self, batch, logs):
        if self.iteration < self.half_iteration:
            rate = self._interpolate(0, self.half_iteration, self.start_rate, self.max_rate)
        elif self.iteration < 2 * self.half_iteration:
            rate = self._interpolate(self.half_iteration, 2 * self.half_iteration,
                                     self.max_rate, self.start_rate)
        else:
            rate = self._interpolate(2 * self.half_iteration, self.iterations,
                                     self.start_rate, self.last_rate)
        self.iteration += 1
        K.set_value(self.model.optimizer.learning_rate, rate)

# %%
dataname
# Out:
# '220408_Data_20'

# %%
tensorboard_cb = keras.callbacks.TensorBoard(run_logdir)
early_stopping_cb = keras.callbacks.EarlyStopping(patience = 10, restore_best_weights = True)
n_epochs = 300
batch_size = 1
onecycle = OneCycleScheduler(math.ceil(len(X_train) / batch_size) * n_epochs, max_rate=0.05)
history = model.fit(X_train, y_train, epochs=n_epochs,
                    validation_data=(X_valid, y_valid),
                    callbacks=[onecycle,early_stopping_cb,tensorboard_cb])
mse_test = model.evaluate(X_test, y_test)
X_new = X_test[:5]
y_pred = model.predict(X_new)
# Out:
# Epoch 1/300
#   1/430 [..............................] - ETA: 6:05 - loss: 2.4336WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.
# Epoch 28/300
# 430/430 [==============================] - 0s 932us/step - loss: 0.0430 - val_loss: 0.0406
# Epoch 29/300
# 430/430 [==============================] - 0s 937us/step - loss: 0.0430 - val_loss: 0.0477
# Epoch 30/300
# 430/430 [==============================] - 0s 931us/step - loss: 0.0412 - val_loss: 0.0414
# Epoch 31/300
# 430/430 [==============================] - 0s 925us/step - loss: 0.0413 - val_loss: 0.0443
# Epoch 32/300
# 430/430 [==============================] - 0s 912us/step - loss: 0.0443 - val_loss: 0.0431
# Epoch 33/300
# 430/430 [==============================] - 0s 919us/step - loss: 0.0428 - val_loss: 0.0438
# 6/6 [==============================] - 0s 798us/step - loss: 0.0436

# %%
#%load_ext tensorboard
#%tensorboard --logdir=./mylog/220408_Data --port=415

# %%
model.save('D:/ME program/2017-PhD/01_research/02Study/34_ballon_like_cover/DeepLearing/SensorCallbi/LABS_v4/myModel/'+dataname+'.h5')

# %%
model = tf.keras.models.load_model('myModel/'+dataname+'.h5')
scaler = load(file_name)
valid_predictions = model.predict(X_valid)

# %%
valid_predictions_df=pd.DataFrame(valid_predictions)
valid_predictions_df.columns = ["valid_r","valid_z"]
#valid_predictions_df.columns = ["valid_r"]
valid_predictions_df
# Out:
#        valid_r   valid_z
# 0    -0.292310  0.879626
# 1     0.552377  0.083854
# 2     0.874410 -0.669792
# 3    -0.970959  0.169354
# 4    -0.426497 -0.635505
# ...        ...       ...
# 3434  0.763707 -0.653917
# 3435  0.122635  0.368227
# 3436 -0.828971 -0.104064
# 3437 -0.820320  0.292761
# 3438 -0.925899  0.310949
#
# [3439 rows x 2 columns]

# %%
k= y_valid.to_numpy()
k_df = pd.DataFrame(k)
k_df.columns  = ["r","z"]
#k_df.columns  = ["r"]
k_df
# Out:
#              r         z
# 0     0.000326  0.799939
# 1     0.333660  0.133272
# 2     1.000326 -0.600061
# 3    -0.999674  0.333272
# 4    -0.666340 -0.666728
# ...        ...       ...
# 3434  0.666993 -0.533395
# 3435  0.666993  0.266605
# 3436 -0.999674 -0.666728
# 3437 -0.666340  0.199939
# 3438 -0.999674  0.266605
#
# [3439 rows x 2 columns]

# %%
k_df.describe()
# Out:
#                  r            z
# count  3439.000000  3439.000000
# mean      0.000520     0.002691
# std       0.663557     0.593124
# min      -0.999674    -1.000061
# 25%      -0.666340    -0.533395
# 50%       0.000326    -0.000061
# 75%       0.666993     0.533272
# max       1.000326     0.999939

# %%
ValidPre = pd.concat( [k_df,valid_predictions_df],axis=1)
ValidPre.head(5)
corr = ValidPre.corr()
print("corr")
for i in range(0,2):    
    print(format(corr[valid_predictions_df.columns[i]][k_df.columns[i]]*100,'.2f')+'%',k_df.columns[i])
corr
# Out:
# corr
# 92.51% r
# 98.03% z
#                 r         z   valid_r   valid_z
# r        1.000000  0.005780  0.925066 -0.019167
# z        0.005780  1.000000 -0.015442  0.980261
# valid_r  0.925066 -0.015442  1.000000 -0.048533
# valid_z -0.019167  0.980261 -0.048533  1.000000

# %%
alpa=0.1
ValidPre.plot(kind="scatter", x= "r",y= "valid_r",alpha = alpa)
plt.savefig('D:/ME program/2017-PhD/01_research/02Study/34_ballon_like_cover/DeepLearing/SensorCallbi/LABS_v4/myFig/'+dataname+'_r.png')
ValidPre.plot(kind="scatter", x= "z",y= "valid_z",alpha = alpa)
plt.savefig('D:/ME program/2017-PhD/01_research/02Study/34_ballon_like_cover/DeepLearing/SensorCallbi/LABS_v4/myFig/'+dataname+'_z.png')
